# %%
from openslide import OpenSlide
from openslide.deepzoom import DeepZoomGenerator
from pathlib import Path

# %%
# select path to your file
tiff_folder = "/Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/"
example_files = [f for f in Path(tiff_folder).glob("*/*.tif*") if f.is_file()]

# %%
# check if metadata can be loaded
def slide_info(slide):
    print("Level count: %d" % slide.level_count)
    print("Level dimensions: " + str(slide.level_dimensions))
    print("Level downsamples: " + str(slide.level_downsamples))
    print("Dimensions: " + str(slide.dimensions))
    if "openslide.mpp-x" in slide.properties:
        slide_mpp = float(slide.properties.get("openslide.mpp-x"))
        print(f"MPP: {slide_mpp}")
    else:
        print("MPP not defined in metadata!")
    if "openslide.objective-power" in slide.properties:
        slide_mag = float(slide.properties.get("openslide.objective-power"))
        print(f"Magnification: {slide_mag}")
    else:
        print("Magnification not defined in metadata!")
    print("Associated images:")
    for ai_key in slide.associated_images.keys():
      print("  " + str(ai_key) + ": " + str(slide.associated_images.get(ai_key)))
    print("Properties:")
    for prop_key in slide.properties.keys():
        print("  Property: " + str(prop_key) + ", value: " + str(slide.properties.get(prop_key)))

for file in example_files:
    print(f"File: {file}")
    slide = OpenSlide(str(file))
    slide_info(slide)
    print("\n")
# Out:
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.1_Big_Loss8_raw/E445_24-1A.1_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((67072, 149760),)
# Level downsamples: (1.0,)
# Dimensions: (67072, 149760)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 149760
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 67072
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.1_Big_Loss8_enhanced/E445_24-1A.1_Wholeslide_EnhancedColors_Extended.tif
# Level count: 1
# Level dimensions: ((67072, 149760),)
# Level downsamples: (1.0,)
# Dimensions: (67072, 149760)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 149760
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 67072
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.3_Big_Lossnat_raw/E445_24-1A.3_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((64256, 172544),)
# Level downsamples: (1.0,)
# Dimensions: (64256, 172544)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 172544
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 64256
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.1_Big_Jpeg_raw/E445_24-1A.1_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((67072, 149760),)
# Level downsamples: (1.0,)
# Dimensions: (67072, 149760)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 67072x149760 (256x256) JPEG/RGB Q=80|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 149760
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 67072
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 67072x149760 (256x256) JPEG/RGB Q=80|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.3_Big_Jpeg_raw/E445_24-1A.3_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((64256, 172544),)
# Level downsamples: (1.0,)
# Dimensions: (64256, 172544)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 64256x172544 (256x256) JPEG/RGB Q=80|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 172544
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 64256
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 64256x172544 (256x256) JPEG/RGB Q=80|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.3_Big_Jpeg_enhanced/E445_24-1A.3_Wholeslide_EnhancedColors_Extended.tif
# Level count: 1
# Level dimensions: ((64256, 172544),)
# Level downsamples: (1.0,)
# Dimensions: (64256, 172544)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 64256x172544 (256x256) JPEG/RGB Q=80|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 172544
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 64256
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 64256x172544 (256x256) JPEG/RGB Q=80|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.1_Big_Jpeg_enhanced/E445_24-1A.1_Wholeslide_EnhancedColors_Extended.tif
# Level count: 1
# Level dimensions: ((67072, 149760),)
# Level downsamples: (1.0,)
# Dimensions: (67072, 149760)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 67072x149760 (256x256) JPEG/RGB Q=80|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 149760
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 67072
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 67072x149760 (256x256) JPEG/RGB Q=80|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.1_Big_Lossnat_raw/E445_24-1A.1_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((67072, 149760),)
# Level downsamples: (1.0,)
# Dimensions: (67072, 149760)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 149760
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 67072
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 67072x149760 (256x256) Lossless compression (DEFLATE)|Date = 08/01/2024|Time = 08:48:55|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.3_Big_Loss8_enhanced/E445_24-1A.3_Wholeslide_EnhancedColors_Extended.tif
# Level count: 1
# Level dimensions: ((64256, 172544),)
# Level downsamples: (1.0,)
# Dimensions: (64256, 172544)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 172544
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 64256
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
#
#
# File: /Users/fhoerst/Fabian-Projekte/DICOM-WSI/Input-Files/3DHistech/Testscans-Fabian/E445_24-1A.3_Big_Loss8_raw/E445_24-1A.3_Wholeslide_Default_Extended.tif
# Level count: 1
# Level dimensions: ((64256, 172544),)
# Level downsamples: (1.0,)
# Dimensions: (64256, 172544)
# MPP: 0.2425326966313954
# Magnification not defined in metadata!
# Associated images:
# Properties:
#   Property: openslide.comment, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: openslide.level-count, value: 1
#   Property: openslide.level[0].downsample, value: 1
#   Property: openslide.level[0].height, value: 172544
#   Property: openslide.level[0].tile-height, value: 256
#   Property: openslide.level[0].tile-width, value: 256
#   Property: openslide.level[0].width, value: 64256
#   Property: openslide.mpp-x, value: 0.2425326966313954
#   Property: openslide.mpp-y, value: 0.24264678364681239
#   Property: openslide.vendor, value: generic-tiff
#   Property: tiff.ImageDescription, value:
# 64256x172544 (256x256) Lossless compression (DEFLATE)|Date = 09/01/2024|Time = 09:16:09|MPP = 0.242591|3dh_PixelSizeX = 0.242535|3dh_PixelSizeY = 0.242647|3dh_Filter = Default|3dh_Profile = Default 20x sRGB|3dh_ScannerHardwareID = P100021B2201
#   Property: tiff.ResolutionUnit, value: centimeter
#   Property: tiff.XResolution, value: 41231.554091026912
#   Property: tiff.YResolution, value: 41212.16794925923
# JPEGFixupTagsSubsamplingSec: Warning, Auto-corrected former TIFF subsampling values [2,2] to match subsampling values inside JPEG compressed data [2,1].
# JPEGFixupTagsSubsamplingSec: Warning, Auto-corrected former TIFF subsampling values [2,2] to match subsampling values inside JPEG compressed data [2,1].
# JPEGFixupTagsSubsamplingSec: Warning, Auto-corrected former TIFF subsampling values [2,2] to match subsampling values inside JPEG compressed data [2,1].
# JPEGFixupTagsSubsamplingSec: Warning, Auto-corrected former TIFF subsampling values [2,2] to match subsampling values inside JPEG compressed data [2,1].

# %%
# Check if thumbnail can be generated
thumbnail = slide.get_thumbnail((1024, 1024))

# %%
# Check if deepzoom and patch extraction works
